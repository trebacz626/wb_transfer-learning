# %%
import os
os.chdir("..")

# %%
from src.data import HeartDataset
from src.utils import plot_image_and_masks

import torch 
from torch.utils.data import  DataLoader

# %%
dataset = HeartDataset("data/affregcommon2mm_roi_ct_train", kind = "ct")
dataloader = DataLoader(dataset, num_workers = 12, batch_size = 20)
len(dataloader)
# Out:
# 96

# %%
for _ in dataloader:
    pass

# %%
iterator = iter(dataloader)
for i in range(50):
    X, y = next(iterator)

# %%
print(X.shape, y.shape)
# Out:
# torch.Size([20, 1, 96, 80]) torch.Size([20, 8, 96, 80])

# %%
plot_image_and_masks(X,y, 4)
